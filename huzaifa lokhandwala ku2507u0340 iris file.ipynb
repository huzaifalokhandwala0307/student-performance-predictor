# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report

iris = load_iris()
x = iris.data
y = iris.target

Xa, Xb, Ya, Yb = train_test_split(x, y, test_size=0.8, random_state=26)

knn = KNeighborsClassifier(n_neighbors=9)

knn.fit(Xa, Ya)

y_preb = knn.predict(Xb)

accuracy = accuracy_score(Yb, y_preb)
print(f"Accuracy: {accuracy:.2f}")
print("Classification Report:")
print(classification_report(Yb, y_preb, target_names=iris.target_names))
# Out:
# Accuracy: 0.95
# Classification Report:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        43
#   versicolor       0.86      1.00      0.92        36
#    virginica       1.00      0.85      0.92        41
#
#     accuracy                           0.95       120
#    macro avg       0.95      0.95      0.95       120
# weighted avg       0.96      0.95      0.95       120
