# %%
from sklearn.preprocessing import LabelEncoder , StandardScaler
from sklearn.model_selection import train_test_split
# import numpy as np  
import pandas as pd

data = {
    'color': ['red', 'blue', 'green', 'blue', 'red', 'green'],
    'size': ['S', 'M', 'L', 'XL', 'M', 'S'],
    "box_number": [1, 2, 1, 3, 2, 1],
    'box_'
    'packed': [0, 1, 0, 1, 2, 0]
}

# x = df[['color', 'size', 'box_number']].
df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)

x = df[['color', 'size', 'box_number']]
y = df['box_packed']

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.4, random_state=42)


# Initialize LabelEncoders for each categorical column
# le = LabelEncoder()
# df_encoded = pd.get_dummies(df,columns= ["color", "size"])
# df["size_encoded"] = pd.get_dummies(df,df["size"])

# print("\nDataFrame after Label Encoding:")
# print(df_encoded)

standard_scaler = StandardScaler()
standard_scaled = standard_scaler.fit_transform(df[['box_number', 'box_packed', "size","color"]].apply(LabelEncoder().fit_transform))


# print("standard scaler output")
# print(pd.DataFrame(standard_scaled, columns=['box_number_scaled', 'box_packed_scaled', 'size_scaled', 'color_scaled']))
print()
print("training data:")
print(x_train)
print(y_train)
# Out:
# Original DataFrame:
#    color size  box_number  box_packed
# 0    red    S           1           0
# 1   blue    M           2           1
# 2  green    L           1           0
# 3   blue   XL           3           1
# 4    red    M           2           2
# 5  green    S           1           0
#
# training data:
#    color size  box_number
# 2  green    L           1
# 4    red    M           2
# 3   blue   XL           3
# 2    0
# 4    2
# 3    1
# Name: box_packed, dtype: int64
